# %% [markdown]
# # Geographic Visualization

# %% [markdown]
# ## This script contains the following points:
# ### 01. Importing libraries
# ### 02. Importing Data
# ### 03. Geographical Visualizations

# %% [markdown]
# ## 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import folium
from folium import plugins
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap
import json
import geopandas as gpd
import pyproj
from pyproj import CRS, Transformer

# %% [markdown]
# ## 02. Importing Data

# %% [markdown]
# #### Note: Source two files - one standard data set ('df_failures') and one JSON/GeoJSON (' Schadensdaten_geo') that complement each other with a common column of location data ('id_failure').

# %%
# Define path
path = r'C:\Users\Sanja\Documents\11-2023 Water Loss Project'

# %%
#Import the standard dataset 'pipes_failures_merged_all'
df_failures = pd.read_excel(os.path.join(path, '02 Data', 'Prepared Data', 'failures_clean.xlsx'), index_col = False)

# %%
df_failures.head(5)
# Out:
#    Unnamed: 0   id_failure  id_pipeline failure_reported_on  cause_of_damage
# 0           0         1196      2067243          1981-11-14              NaN
# 1           1         1443      2074816          1998-11-12              NaN
# 2           2  83500002/15      2068165          2006-07-27              NaN
# 3           3         1433      2062991          1998-01-13              NaN
# 4           4         1990      2056069          2004-08-10              NaN

# %% [markdown]
# ### Import the Geo Dataset

# %% [markdown]
# #### Note: The geodataset is an excel file 'Schadensdaten_geo' where the coordinates are given in a projected coordinate system (UTM Zone 32N), so we need to covert them to latitude and longitude. We can use  the geopandas library for spatial data handling and the pyproj.CRS class for CRS definitions.

# %% [markdown]
# #### a. Convert the coordinates X and Y from UTM Zone 32N to to latitude and longitude

# %%
# Read the Excel file
excel_file_path = os.path.join(path, '02 Data', 'Original Data', 'Schadensdaten_geo.xlsx')
df = pd.read_excel(excel_file_path)

# Convert DataFrame to GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['X'], df['Y']))

# Define the input CRS 
input_crs = CRS('EPSG:32632')  # UTM Zone 32N

# Define the output CRS (standard geographic coordinate system - WGS 84)
output_crs = CRS('EPSG:4326')

# Create a PyProj transformer
transformer = Transformer.from_crs(input_crs, output_crs, always_xy=True)

# Transform X and Y coordinates to latitude and longitude
gdf = gdf.set_crs(input_crs)
gdf = gdf.to_crs(output_crs)

# Save the transformed GeoDataFrame back to Excel
output_excel_file_path = os.path.join(path, '02 Data', 'Prepared Data', 'Schadensdaten_geo_transformed.xlsx')
gdf.to_excel(output_excel_file_path, index=False)

# Display the transformed GeoDataFrame
print(gdf)
# Out:
#          id_failure   Gemeinde            Straße     ENum           Y  \
# 0              1070  Pforzheim     Belfortstraße  1656709  5417392.97
# 1              2068  Pforzheim     Belfortstraße  1753200  5417429.32
# 2     82300002/1007  Pforzheim     Belfortstraße  1820500  5417296.47
# 3              1001  Pforzheim      Belremstraße  1769375  5414689.30
# 4              1681  Pforzheim      Belremstraße  1656724  5414577.74
# ...             ...        ...               ...      ...         ...
# 1459   82300002/903  Pforzheim  Zum Geigersgrund  1791217  5418493.87
# 1460           1820  Pforzheim  Zum Höhenfreibad  1652716  5418663.18
# 1461           1821  Pforzheim  Zum Höhenfreibad  1652718  5418661.76
# 1462   82300002/906  Pforzheim  Zum Höhenfreibad  1808207  5418641.87
# 1463  82300002/1091  Pforzheim  Zum Lachenwäldle  1885987  5416400.07
#
#               X                  geometry
# 0     477349.61  POINT (8.69089 48.90906)
# 1     477353.40  POINT (8.69094 48.90939)
# 2     477308.70  POINT (8.69033 48.90819)
# 3     476864.80  POINT (8.68442 48.88472)
# 4     476706.49  POINT (8.68227 48.88372)
# ...         ...                       ...
# 1459  476564.60  POINT (8.68011 48.91894)
# 1460  479206.14  POINT (8.71616 48.92056)
# 1461  479207.73  POINT (8.71618 48.92054)
# 1462  479196.31  POINT (8.71603 48.92036)
# 1463  474873.36  POINT (8.65716 48.90004)
#
# [1464 rows x 7 columns]

# %%
# Read the Excel file
excel_file_path = os.path.join(path, '02 Data', 'Original Data', 'Schadensdaten_geo.xlsx')
df = pd.read_excel(excel_file_path)

# Convert DataFrame to GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['X'], df['Y']))

# Define the input CRS 
input_crs = CRS('EPSG:32632')  # UTM Zone 32N

# Set the CRS for the GeoDataFrame
gdf = gdf.set_crs(input_crs)

# Define the output CRS (standard geographic coordinate system - WGS 84)
output_crs = CRS('EPSG:4326')

# Create a PyProj transformer
transformer = Transformer.from_crs(input_crs, output_crs, always_xy=True)

# Transform X and Y coordinates to latitude and longitude
gdf['Longitude'], gdf['Latitude'] = transformer.transform(gdf['geometry'].x, gdf['geometry'].y)

# Save the transformed GeoDataFrame back to Excel
output_excel_file_path = os.path.join(path, '02 Data', 'Prepared Data', 'Schadensdaten_geo_transformed.xlsx')
gdf.to_excel(output_excel_file_path, index=False)

# Display the transformed GeoDataFrame
print(gdf)
# Out:
#          id_failure   Gemeinde            Straße     ENum           Y  \
# 0              1070  Pforzheim     Belfortstraße  1656709  5417392.97
# 1              2068  Pforzheim     Belfortstraße  1753200  5417429.32
# 2     82300002/1007  Pforzheim     Belfortstraße  1820500  5417296.47
# 3              1001  Pforzheim      Belremstraße  1769375  5414689.30
# 4              1681  Pforzheim      Belremstraße  1656724  5414577.74
# ...             ...        ...               ...      ...         ...
# 1459   82300002/903  Pforzheim  Zum Geigersgrund  1791217  5418493.87
# 1460           1820  Pforzheim  Zum Höhenfreibad  1652716  5418663.18
# 1461           1821  Pforzheim  Zum Höhenfreibad  1652718  5418661.76
# 1462   82300002/906  Pforzheim  Zum Höhenfreibad  1808207  5418641.87
# 1463  82300002/1091  Pforzheim  Zum Lachenwäldle  1885987  5416400.07
#
#               X                        geometry  Longitude   Latitude
# 0     477349.61  POINT (477349.610 5417392.970)   8.690887  48.909064
# 1     477353.40  POINT (477353.400 5417429.320)   8.690937  48.909391
# 2     477308.70  POINT (477308.700 5417296.470)   8.690335  48.908194
# 3     476864.80  POINT (476864.800 5414689.300)   8.684424  48.884725
# 4     476706.49  POINT (476706.490 5414577.740)   8.682271  48.883715
# ...         ...                             ...        ...        ...
# 1459  476564.60  POINT (476564.600 5418493.870)   8.680111  48.918938
# 1460  479206.14  POINT (479206.140 5418663.180)   8.716159  48.920555
# 1461  479207.73  POINT (479207.730 5418661.760)   8.716180  48.920543
# 1462  479196.31  POINT (479196.310 5418641.870)   8.716026  48.920363
# 1463  474873.36  POINT (474873.360 5416400.070)   8.657155  48.900037
#
# [1464 rows x 9 columns]

# %% [markdown]
# #### b. Covert the transformed excel file 'Schadensdaten_geo_transformed.xlsx' to GeoJSON file

# %%
# Read Excel file into a DataFrame
df = pd.read_excel(os.path.join(path, '02 Data', 'Prepared Data', 'Schadensdaten_geo_transformed.xlsx'))

# Create a GeoDataFrame from the DataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['Longitude'], df['Latitude']))

# Specify the full path for the output GeoJSON file
output_path = os.path.join(path, '02 Data', 'Prepared Data', 'Schadensdaten_geo.geojson')

# Write GeoJSON data to the specified file
gdf.to_file(output_path, driver='GeoJSON')

# %%
# Import "geojson" file
failuers_geo = gpd.read_file(os.path.join(path, '02 Data', 'Prepared Data', 'Schadensdaten_geo.geojson'))

# %%
failuers_geo
# Out:
#          id_failure   Gemeinde            Straße     ENum           Y  \
# 0              1070  Pforzheim     Belfortstraße  1656709  5417392.97
# 1              2068  Pforzheim     Belfortstraße  1753200  5417429.32
# 2     82300002/1007  Pforzheim     Belfortstraße  1820500  5417296.47
# 3              1001  Pforzheim      Belremstraße  1769375  5414689.30
# 4              1681  Pforzheim      Belremstraße  1656724  5414577.74
# ...             ...        ...               ...      ...         ...
# 1459   82300002/903  Pforzheim  Zum Geigersgrund  1791217  5418493.87
# 1460           1820  Pforzheim  Zum Höhenfreibad  1652716  5418663.18
# 1461           1821  Pforzheim  Zum Höhenfreibad  1652718  5418661.76
# 1462   82300002/906  Pforzheim  Zum Höhenfreibad  1808207  5418641.87
# 1463  82300002/1091  Pforzheim  Zum Lachenwäldle  1885987  5416400.07
#
#               X  Longitude   Latitude                  geometry
# 0     477349.61   8.690887  48.909064  POINT (8.69089 48.90906)
# 1     477353.40   8.690937  48.909391  POINT (8.69094 48.90939)
# 2     477308.70   8.690335  48.908194  POINT (8.69033 48.90819)
# 3     476864.80   8.684424  48.884725  POINT (8.68442 48.88472)
# 4     476706.49   8.682271  48.883715  POINT (8.68227 48.88372)
# ...         ...        ...        ...                       ...
# 1459  476564.60   8.680111  48.918938  POINT (8.68011 48.91894)
# 1460  479206.14   8.716159  48.920555  POINT (8.71616 48.92056)
# 1461  479207.73   8.716180  48.920543  POINT (8.71618 48.92054)
# 1462  479196.31   8.716026  48.920363  POINT (8.71603 48.92036)
# 1463  474873.36   8.657155  48.900037  POINT (8.65716 48.90004)
#
# [1464 rows x 9 columns]

# %% [markdown]
# ### 03. Geographical Visualizations

# %%
# Create a data frame with just the id_failure and the values for failures we want plotted

data_to_plot = df_failures[['id_failure','cause_of_damage']]
data_to_plot.head()
# Out:
#     id_failure  cause_of_damage
# 0         1196              NaN
# 1         1443              NaN
# 2  83500002/15              NaN
# 3         1433              NaN
# 4         1990              NaN

# %%
# Open and read the GeoJSON file
with open(r'C:\Users\Sanja\Documents\11-2023 Water Loss Project\02 Data\Prepared Data\Schadensdaten_geo.geojson', 'r') as f:
    # Load the JSON data
    data = json.load(f)

# Iterating through the list of features
for feature in data['features']:
    # Print the properties of each feature
    print("Feature Properties:")
    for key, value in feature['properties'].items():
        print(f"  {key}: {value}")

    # Print the geometry of each feature
    print("Feature Geometry:")
    print(f"  Type: {feature['geometry']['type']}")
    print(f"  Coordinates: {feature['geometry']['coordinates']}")

    print("\n" + "-" * 30 + "\n")  # Separating features for better readability
# Out:
# Feature Properties:
#   id_failure: 1070
#   Gemeinde: Pforzheim
#   StraÃŸe: BelfortstraÃŸe
#   ENum: 1656709
#   Y: 5417392.97
#   X: 477349.61
#   Longitude: 8.690887438392448
#   Latitude: 48.90906384828052
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.690887438392448, 48.90906384828052]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 2068
#   Gemeinde: Pforzheim
#   StraÃŸe: BelfortstraÃŸe
#   ENum: 1753200
#   Y: 5417429.32
#   X: 477353.4
#   Longitude: 8.690937143454097
#   Latitude: 48.90939097796691
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.690937143454097, 48.90939097796691]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1007
#   Gemeinde: Pforzheim
#   StraÃŸe: BelfortstraÃŸe
#   ENum: 1820500
#   Y: 5417296.47
#   X: 477308.7
#   Longitude: 8.690334507586583
#   Latitude: 48.90819427243528
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.690334507586583, 48.90819427243528]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1001
#   Gemeinde: Pforzheim
#   StraÃŸe: BelremstraÃŸe
#   ENum: 1769375
#   Y: 5414689.3
#   X: 476864.8
#   Longitude: 8.684424416876592
#   Latitude: 48.88472467948091
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.684424416876592, 48.88472467948091]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1681
#   Gemeinde: Pforzheim
#   StraÃŸe: BelremstraÃŸe
#   ENum: 1656724
#   Y: 5414577.74
#   X: 476706.49
#   Longitude: 8.682271382184158
#   Latitude: 48.88371519405548
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.682271382184158, 48.88371519405548]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1696
#   Gemeinde: Pforzheim
#   StraÃŸe: BelremstraÃŸe
#   ENum: 1656726
#   Y: 5414444.76
#   X: 476453.48
#   Longitude: 8.678827986335106
#   Latitude: 48.88250939108126
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.678827986335106, 48.88250939108126]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1697
#   Gemeinde: Pforzheim
#   StraÃŸe: BelremstraÃŸe
#   ENum: 1656728
#   Y: 5413966.79
#   X: 476060.28
#   Longitude: 8.673492858540785
#   Latitude: 48.87819467454156
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.673492858540785, 48.87819467454156]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1175
#   Gemeinde: Pforzheim
#   StraÃŸe: BelremstraÃŸe
#   ENum: 1908046
#   Y: 5413979.82
#   X: 476072.08
#   Longitude: 8.673653030192822
#   Latitude: 48.87831234358177
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.673653030192822, 48.87831234358177]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1108
#   Gemeinde: Pforzheim
#   StraÃŸe: BenckiserstraÃŸe
#   ENum: 1498297
#   Y: 5416972.7
#   X: 477078.51
#   Longitude: 8.687211359150643
#   Latitude: 48.90527328036752
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.687211359150643, 48.90527328036752]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1679
#   Gemeinde: Pforzheim
#   StraÃŸe: BenckiserstraÃŸe
#   ENum: 1656710
#   Y: 5416968.74
#   X: 477078.98
#   Longitude: 8.687217995029394
#   Latitude: 48.90523767506383
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.687217995029394, 48.90523767506383]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1124
#   Gemeinde: Pforzheim
#   StraÃŸe: BergmannstraÃŸe
#   ENum: 1623308
#   Y: 5413611.03
#   X: 480627.51
#   Longitude: 8.735800110152248
#   Latitude: 48.87515391018788
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.735800110152248, 48.87515391018788]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1883
#   Gemeinde: Pforzheim
#   StraÃŸe: BergmannstraÃŸe
#   ENum: 1652540
#   Y: 5413648.37
#   X: 480740.49
#   Longitude: 8.737339143468581
#   Latitude: 48.87549333023324
# Feature Geometry:
#   Type: Point
#   Coordinates: [8

#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/891
#   Gemeinde: Pforzheim
#   StraÃŸe: BrendstraÃŸe
#   ENum: 1807948
#   Y: 5416843.97
#   X: 474717.54
#   Longitude: 8.655001911520845
#   Latitude: 48.90402339698457
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.655001911520845, 48.90402339698457]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1077
#   Gemeinde: Pforzheim
#   StraÃŸe: Breslauer StraÃŸe
#   ENum: 1658047
#   Y: 5416465.03
#   X: 480605.58
#   Longitude: 8.735365589406525
#   Latitude: 48.90082694128275
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.735365589406525, 48.90082694128275]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1511
#   Gemeinde: Pforzheim
#   StraÃŸe: Breslauer StraÃŸe
#   ENum: 2011160
#   Y: 5416539.31
#   X: 480540.96
#   Longitude: 8.734480328064327
#   Latitude: 48.90149311336958
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.734480328064327, 48.90149311336958]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1129
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1409808
#   Y: 5417864.39
#   X: 478661.35
#   Longitude: 8.70876401360192
#   Latitude: 48.9133511629889
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.70876401360192, 48.9133511629889]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1893
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1680947
#   Y: 5417839.44
#   X: 478651.66
#   Longitude: 8.708633068687751
#   Latitude: 48.91312638783614
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.708633068687751, 48.91312638783614]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 2073
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1763557
#   Y: 5418072.63
#   X: 478759.94
#   Longitude: 8.710098741186128
#   Latitude: 48.91522780410902
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.710098741186128, 48.91522780410902]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 2088
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1753245
#   Y: 5418222.6
#   X: 478826.65
#   Longitude: 8.711001458209907
#   Latitude: 48.91657916433974
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.711001458209907, 48.91657916433974]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1109
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1894039
#   Y: 5417978.98
#   X: 478713.77
#   Longitude: 8.709473469897068
#   Latitude: 48.91438377727823
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.709473469897068, 48.91438377727823]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1416
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1983477
#   Y: 5417982.62
#   X: 478715.35
#   Longitude: 8.709494844482867
#   Latitude: 48.91441657570883
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.709494844482867, 48.91441657570883]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1416
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1983471
#   Y: 5417928.76
#   X: 478691.41
#   Longitude: 8.709170914404119
#   Latitude: 48.91393124733029
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.709170914404119, 48.91393124733029]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1449
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1998227
#   Y: 5417908.43
#   X: 478682.22
#   Longitude: 8.709046548915225
#   Latitude: 48.91374804970808
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.709046548915225, 48.91374804970808]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300023/232
#   Gemeinde: Pforzheim
#   StraÃŸe: Brettener StraÃŸe
#   ENum: 1971975
#   Y: 5417891.34
#   X: 478674.3
#   Longitude: 8.7089393481817
#   Latitude: 48.91359404155207
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.7089393481817, 48.91359404155207]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1374
#   Gemeinde: Pforzheim
#   StraÃŸe: BrÃ¶machweg
#   ENum: 1539523
#   Y: 5419766.5
#   X: 481910.0
#   Longitude: 8.753017689699993
#   Latitude: 48.93056532776492
# Feature Geometry:
#   Type: Point
#   Coordinates: [8
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.670117029122734, 48.90413131326441]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/923
#   Gemeinde: Pforzheim
#   StraÃŸe: BÃ¼chenbronner StraÃŸe
#   ENum: 1789713
#   Y: 5416802.31
#   X: 475860.81
#   Longitude: 8.670604873159139
#   Latitude: 48.90369425300283
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.670604873159139, 48.90369425300283]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 83200013/117
#   Gemeinde: Pforzheim
#   StraÃŸe: BÃ¼chenbronner StraÃŸe
#   ENum: 1998229
#   Y: 5416235.48
#   X: 475837.27
#   Longitude: 8.670317198587211
#   Latitude: 48.89859434646647
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.670317198587211, 48.89859434646647]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1180
#   Gemeinde: Pforzheim
#   StraÃŸe: BÃ¼chenbronner Weg
#   ENum: 1911091
#   Y: 5413969.39
#   X: 476062.64
#   Longitude: 8.673524893162364
#   Latitude: 48.87821815439349
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.673524893162364, 48.87821815439349]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1219
#   Gemeinde: Pforzheim
#   StraÃŸe: BÃ¼chenbronner Weg
#   ENum: 1926236
#   Y: 5413974.36
#   X: 476067.14
#   Longitude: 8.673585975486093
#   Latitude: 48.87826303657511
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.673585975486093, 48.87826303657511]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1237
#   Gemeinde: Pforzheim
#   StraÃŸe: BunsenstraÃŸe
#   ENum: 1507543
#   Y: 5416656.01
#   X: 477257.16
#   Longitude: 8.689666834677885
#   Latitude: 48.90243103874427
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.689666834677885, 48.90243103874427]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1487
#   Gemeinde: Pforzheim
#   StraÃŸe: BunsenstraÃŸe
#   ENum: 1658057
#   Y: 5416436.34
#   X: 477323.03
#   Longitude: 8.690577836299251
#   Latitude: 48.90045738167695
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.690577836299251, 48.90045738167695]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1802
#   Gemeinde: Pforzheim
#   StraÃŸe: BunsenstraÃŸe
#   ENum: 1634418
#   Y: 5416688.67
#   X: 477252.1
#   Longitude: 8.689595971010485
#   Latitude: 48.90272465043849
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.689595971010485, 48.90272465043849]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1377
#   Gemeinde: Pforzheim
#   StraÃŸe: BunsenstraÃŸe
#   ENum: 1976457
#   Y: 5416484.04
#   X: 477234.6
#   Longitude: 8.689368588252277
#   Latitude: 48.90088323005327
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.689368588252277, 48.90088323005327]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300023/186
#   Gemeinde: Pforzheim
#   StraÃŸe: BunsenstraÃŸe
#   ENum: 1887241
#   Y: 5416570.56
#   X: 477240.99
#   Longitude: 8.689450955849127
#   Latitude: 48.90166176755518
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.689450955849127, 48.90166176755518]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1310
#   Gemeinde: Pforzheim
#   StraÃŸe: Calwer StraÃŸe
#   ENum: 1465888
#   Y: 5416258.54
#   X: 477997.12
#   Longitude: 8.69978508794635
#   Latitude: 48.89888226607552
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.69978508794635, 48.89888226607552]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1513
#   Gemeinde: Pforzheim
#   StraÃŸe: Calwer StraÃŸe
#   ENum: 1658244
#   Y: 5416530.3
#   X: 478064.76
#   Longitude: 8.700693381780876
#   Latitude: 48.90132932278904
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.700693381780876, 48.90132932278904]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1514
#   Gemeinde: Pforzheim
#   StraÃŸe: Calwer StraÃŸe
#   ENum: 1658246
#   Y: 5416467.22
#   X: 478034.38
#   Longitude: 8.700282245207335
#   Latitude: 48.90076080070364
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.700282245207335, 48.90076080070364]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1539
#   Gemeinde: Pforzheim
#   StraÃŸe: Calwer StraÃŸe
#   ENum: 2019943
#   Y: 5416442.61
#   X: 478031.53
#   Longitude: 8.700244681794393
#   Latitude: 48.90053931671068
# Feature Geometry:
#   Type: Point
#   Coordinates: [8
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.707632350809583, 48.91240626285308]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1050
#   Gemeinde: Pforzheim
#   StraÃŸe: DammstraÃŸe
#   ENum: 1730202
#   Y: 5417974.13
#   X: 479730.27
#   Longitude: 8.723347305413833
#   Latitude: 48.91437426186608
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.723347305413833, 48.91437426186608]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1213
#   Gemeinde: Pforzheim
#   StraÃŸe: DammstraÃŸe
#   ENum: 1658317
#   Y: 5417899.9
#   X: 479586.04
#   Longitude: 8.721382510706373
#   Latitude: 48.91370177643507
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.721382510706373, 48.91370177643507]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1532
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 1579160
#   Y: 5416352.52
#   X: 480479.16
#   Longitude: 8.733646001871355
#   Latitude: 48.89981086669795
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.733646001871355, 48.89981086669795]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1533
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 1579165
#   Y: 5416353.03
#   X: 480465.6
#   Longitude: 8.73346095883316
#   Latitude: 48.8998150270258
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.73346095883316, 48.8998150270258]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1672
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 1633717
#   Y: 5416382.37
#   X: 480508.97
#   Longitude: 8.734051318109396
#   Latitude: 48.90008032632783
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.734051318109396, 48.90008032632783]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 2056
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 1762825
#   Y: 5416307.38
#   X: 480508.1
#   Longitude: 8.734043026460503
#   Latitude: 48.89940571315837
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.734043026460503, 48.89940571315837]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 2057
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 1759095
#   Y: 5416352.53
#   X: 480478.86
#   Longitude: 8.73364190806048
#   Latitude: 48.8998109472007
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.73364190806048, 48.8998109472007]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 2082
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 1579172
#   Y: 5416394.63
#   X: 480509.19
#   Longitude: 8.734053734784734
#   Latitude: 48.90019062023881
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.734053734784734, 48.90019062023881]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1093
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 1887426
#   Y: 5416353.37
#   X: 480446.13
#   Longitude: 8.733195285236649
#   Latitude: 48.89981747126194
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.733195285236649, 48.89981747126194]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1529
#   Gemeinde: Pforzheim
#   StraÃŸe: Danziger StraÃŸe
#   ENum: 2016996
#   Y: 5416353.37
#   X: 480445.98
#   Longitude: 8.733193238570014
#   Latitude: 48.89981746652695
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.733193238570014, 48.89981746652695]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1085
#   Gemeinde: Pforzheim
#   StraÃŸe: Davosweg
#   ENum: 1879784
#   Y: 5415277.08
#   X: 477202.05
#   Longitude: 8.68899181347159
#   Latitude: 48.89002464594164
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.68899181347159, 48.89002464594164]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1563
#   Gemeinde: Pforzheim
#   StraÃŸe: Davosweg
#   ENum: 2034704
#   Y: 5415277.86
#   X: 477213.92
#   Longitude: 8.689153697269138
#   Latitude: 48.89003209914766
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.689153697269138, 48.89003209914766]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1568
#   Gemeinde: Pforzheim
#   StraÃŸe: Davosweg
#   ENum: 2035125
#   Y: 5415301.99
#   X: 477104.22
#   Longitude: 8.687655847754373
#   Latitude: 48.89024512073263
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.687655847754373, 48.89024512073263]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1012
#   Gemeinde: Pforzheim
#   StraÃŸe: DegenfeldstraÃŸe
#   ENum: 1658309
#   Y: 5416259.99
#   X: 477543.19
#   Longitude: 8.693591521858918
#   Latitude: 48.89887902039339
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.693591521858918, 48.89887902039339]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1013
#   Gemeinde: Pforzheim
#   StraÃŸe: DegenfeldstraÃŸe
#   ENum: 1658311
#   Y: 5416271.23
#   X: 477633.06
#   Longitude: 8.694817105416229
#   Latitude: 48.89898338287969
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.694817105416229, 48.89898338287969]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1019
#   Gemeinde: Pforzheim
#   StraÃŸe: DegenfeldstraÃŸe
#   ENum: 1658315
#   Y: 5416255.18
#   X: 477505.38
#   Longitude: 8.693075901806566
#   Latitude: 48.8988343795103
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.693075901806566, 48.8988343795103]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1029
#   Gemeinde: Pforzheim
#   StraÃŸe: DegenfeldstraÃŸe
#   ENum: 1658313
#   Y: 5416255.47
#   X: 477507.67
#   Longitude: 8.693107130890782
#   Latitude: 48.89883707139917
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.693107130890782, 48.89883707139917]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1096
#   Gemeinde: Pforzheim
#   StraÃŸe: Deichlerweg
#   ENum: 1658319
#   Y: 5418105.27
#   X: 476197.03
#   Longitude: 8.675116756559403
#   Latitude: 48.9154281902014
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.675116756559403, 48.9154281902014]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1121
#   Gemeinde: Pforzheim
#   StraÃŸe: Deichlerweg
#   ENum: 1410012
#   Y: 5418378.74
#   X: 476218.26
#   Longitude: 8.67539057745799
#   Latitude: 48.91788903352075
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.67539057745799, 48.91788903352075]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1209
#   Gemeinde: Pforzheim
#   StraÃŸe: Deichlerweg
#   ENum: 1409972
#   Y: 5418597.04
#   X: 476235.43
#   Longitude: 8.675612219716728
#   Latitude: 48.91985343222716
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.675612219716728, 48.91985343222716]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1037
#   Gemeinde: Pforzheim
#   StraÃŸe: DennachstraÃŸe
#   ENum: 1670777
#   Y: 5416230.34
#   X: 479153.35
#   Longitude: 8.715562320737101
#   Latitude: 48.89866857727627
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.715562320737101, 48.89866857727627]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1092
#   Gemeinde: Pforzheim
#   StraÃŸe: DennigstraÃŸe
#   ENum: 1658327
#   Y: 5415836.61
#   X: 474691.29
#   Longitude: 8.654706142885479
#   Latitude: 48.89496050668674
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.654706142885479, 48.89496050668674]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1093
#   Gemeinde: Pforzheim
#   StraÃŸe: DennigstraÃŸe
#   ENum: 1658329
#   Y: 5415835.27
#   X: 474688.69
#   Longitude: 8.654670754053969
#   Latitude: 48.89494834634442
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.654670754053969, 48.89494834634442]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1094
#   Gemeinde: Pforzheim
#   StraÃŸe: DennigstraÃŸe
#   ENum: 1658331
#   Y: 5415627.08
#   X: 474335.78
#   Longitude: 8.64986907677914
#   Latitude: 48.89306103110153
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.64986907677914, 48.89306103110153]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1095
#   Gemeinde: Pforzheim
#   StraÃŸe: DennigstraÃŸe
#   ENum: 1658333
#   Y: 5415625.31
#   X: 474333.08
#   Longitude: 8.649832353231822
#   Latitude: 48.89304499701928
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.649832353231822, 48.89304499701928]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1321
#   Gemeinde: Pforzheim
#   StraÃŸe: DennigstraÃŸe
#   ENum: 1690326
#   Y: 5415823.38
#   X: 474665.6
#   Longitude: 8.654356474128544
#   Latitude: 48.89484044470678
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.654356474128544, 48.89484044470678]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1236
#   Gemeinde: Pforzheim
#   StraÃŸe: DennigstraÃŸe
#   ENum: 1931129
#   Y: 5415832.91
#   X: 474684.09
#   Longitude: 8.65460814241915
#   Latitude: 48.89492692874196
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.65460814241915, 48.89492692874196]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1638
#   Gemeinde: Pforzheim
#   StraÃŸe: Dietlinger StraÃŸe
#   ENum: 1658428
#   Y: 5417433.04
#   X: 475232.62
#   Longitude: 8.661994696672703
#   Latitude: 48.90934325021448
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.661994696672703, 48.90934325021448]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1775
#   Gemeinde: Pforzheim
#   StraÃŸe: Dietlinger StraÃŸe
#   ENum: 1654447
#   Y: 5417828.7
#   X: 474889.3
#   Longitude: 8.65728508566833
#   Latitude: 48.91288862061278
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.65728508566833, 48.91288862061278]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1261
#   Gemeinde: Pforzheim
#   StraÃŸe: Dollbronner StraÃŸe
#   ENum: 1561560
#   Y: 5413012.52
#   X: 480783.61
#   Longitude: 8.737957080706096
#   Latitude: 48.86977473841021
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.737957080706096, 48.86977473841021]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 2074
#   Gemeinde: Pforzheim
#   StraÃŸe: Dollbronner StraÃŸe
#   ENum: 1535632
#   Y: 5413038.43
#   X: 480792.02
#   Longitude: 8.738070545210114
#   Latitude: 48.87000807824261
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.738070545210114, 48.87000807824261]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1499
#   Gemeinde: Pforzheim
#   StraÃŸe: Dollbronner StraÃŸe
#   ENum: 2018319
#   Y: 5412971.88
#   X: 480770.08
#   Longitude: 8.737774492251331
#   Latitude: 48.86940873264867
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.737774492251331, 48.86940873264867]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1384
#   Gemeinde: Pforzheim
#   StraÃŸe: DorfÃ¤ckerweg
#   ENum: 1540293
#   Y: 5420089.17
#   X: 481320.88
#   Longitude: 8.744959747046165
#   Latitude: 48.93345044573305
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.744959747046165, 48.93345044573305]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1646
#   Gemeinde: Pforzheim
#   StraÃŸe: Dr.-Brandenburg-StraÃŸe
#   ENum: 1658611
#   Y: 5416615.52
#   X: 477890.27
#   Longitude: 8.698307883901483
#   Latitude: 48.90208972798857
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.698307883901483, 48.90208972798857]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1123
#   Gemeinde: Pforzheim
#   StraÃŸe: Drei-Eichen-Weg
#   ENum: 1623306
#   Y: 5412382.91
#   X: 477798.92
#   Longitude: 8.697291288774444
#   Latitude: 48.86401128038089
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.697291288774444, 48.86401128038089]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1322
# ...
#   Y: 5417079.85
#   X: 476021.74
#   Longitude: 8.672784531529631
#   Latitude: 48.90619714818374
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.672784531529631, 48.90619714818374]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1981
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 1652745
#   Y: 5417143.31
#   X: 476428.52
#   Longitude: 8.678331833012734
#   Latitude: 48.90678362623435
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.678331833012734, 48.90678362623435]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1058
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 1869222
#   Y: 5417088.22
#   X: 476036.37
#   Longitude: 8.672983682768674
#   Latitude: 48.90627300776127
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.672983682768674, 48.90627300776127]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1146
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 1904129
#   Y: 5417176.69
#   X: 476140.83
#   Longitude: 8.67440398690587
#   Latitude: 48.90707288320079
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.67440398690587, 48.90707288320079]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1266
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 1935045
#   Y: 5417125.54
#   X: 477906.3
#   Longitude: 8.698499015425302
#   Latitude: 48.90667825717883
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.698499015425302, 48.90667825717883]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1399
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 1983483
#   Y: 5416959.35
#   X: 475759.58
#   Longitude: 8.669214223832796
#   Latitude: 48.90510297098213
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.669214223832796, 48.90510297098213]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1484
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 2007721
#   Y: 5417229.55
#   X: 477604.83
#   Longitude: 8.694379369487784
#   Latitude: 48.90760306470295
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.694379369487784, 48.90760306470295]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1501
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 2010594
#   Y: 5417230.13
#   X: 477663.07
#   Longitude: 8.695174110983892
#   Latitude: 48.90761038557264
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.695174110983892, 48.90761038557264]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/934
#   Gemeinde: Pforzheim
#   StraÃŸe: Westliche Karl-Friedrich-Str.
#   ENum: 1789086
#   Y: 5416973.24
#   X: 475814.62
#   Longitude: 8.669964466096854
#   Latitude: 48.90523007186874
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.669964466096854, 48.90523007186874]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1403
#   Gemeinde: Pforzheim
#   StraÃŸe: Westring
#   ENum: 1979607
#   Y: 5412554.17
#   X: 475015.34
#   Longitude: 8.659327758944766
#   Latitude: 48.86544599420726
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.659327758944766, 48.86544599420726]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1438
#   Gemeinde: Pforzheim
#   StraÃŸe: Westring
#   ENum: 1992971
#   Y: 5413302.6
#   X: 474812.52
#   Longitude: 8.656516228440363
#   Latitude: 48.87217041254254
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.656516228440363, 48.87217041254254]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1003
#   Gemeinde: Pforzheim
#   StraÃŸe: Wilhelm-Becker-StraÃŸe
#   ENum: 1758673
#   Y: 5418316.27
#   X: 475623.12
#   Longitude: 8.667271073937794
#   Latitude: 48.91730392985435
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.667271073937794, 48.91730392985435]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1007
#   Gemeinde: Pforzheim
#   StraÃŸe: Wilhelm-Becker-StraÃŸe
#   ENum: 1758671
#   Y: 5418315.68
#   X: 475617.43
#   Longitude: 8.667193445681747
#   Latitude: 48.91729839837544
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.667193445681747, 48.91729839837544]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1462
#   Gemeinde: Pforzheim
#   StraÃŸe: Wilhelm-Becker-StraÃŸe
#   ENum: 2018253
#   Y: 5418237.47
#   X: 475875.86
#   Longitude: 8.670725413577545
#   Latitude: 48.91660497715534
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.670725413577545, 48.91660497715534]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1521
#   Gemeinde: Pforzheim
#   StraÃŸe: Wilhelm-Becker-StraÃŸe
#   ENum: 2018251
#   Y: 5418237.57
#   X: 475875.88
#   Longitude: 8.670725680643848
#   Latitude: 48.91660587749455
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.670725680643848, 48.91660587749455]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1481
#   Gemeinde: Pforzheim
#   StraÃŸe: WilhelmstraÃŸe
#   ENum: 1598601
#   Y: 5410567.04
#   X: 480132.33
#   Longitude: 8.72919474816227
#   Latitude: 48.84775531808415
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.72919474816227, 48.84775531808415]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1482
#   Gemeinde: Pforzheim
#   StraÃŸe: WilhelmstraÃŸe
#   ENum: 1598603
#   Y: 5410586.52
#   X: 480241.53
#   Longitude: 8.730682236140758
#   Latitude: 48.84793404179991
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.730682236140758, 48.84793404179991]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1310
#   Gemeinde: Pforzheim
#   StraÃŸe: WilhelmstraÃŸe
#   ENum: 1961536
#   Y: 5410537.37
#   X: 480195.7
#   Longitude: 8.730059934285057
#   Latitude: 48.84749043955464
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.730059934285057, 48.84749043955464]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1212
#   Gemeinde: Pforzheim
#   StraÃŸe: Wolfsbergallee
#   ENum: 1401072
#   Y: 5418710.66
#   X: 478203.49
#   Longitude: 8.7024698876967
#   Latitude: 48.92094794158012
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.7024698876967, 48.92094794158012]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1636
#   Gemeinde: Pforzheim
#   StraÃŸe: Wolfsbergallee
#   ENum: 1652759
#   Y: 5418353.93
#   X: 478372.58
#   Longitude: 8.704796905704372
#   Latitude: 48.91774486389003
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.704796905704372, 48.91774486389003]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1225
#   Gemeinde: Pforzheim
#   StraÃŸe: Wolfsbergallee
#   ENum: 1931482
#   Y: 5418430.39
#   X: 478745.82
#   Longitude: 8.70988738648677
#   Latitude: 48.91844559664301
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.70988738648677, 48.91844559664301]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1217
#   Gemeinde: Pforzheim
#   StraÃŸe: Wurmberger StraÃŸe
#   ENum: 1435685
#   Y: 5416538.95
#   X: 480545.49
#   Longitude: 8.73454215662018
#   Latitude: 48.90149001722138
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.73454215662018, 48.90149001722138]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1671
#   Gemeinde: Pforzheim
#   StraÃŸe: Wurmberger StraÃŸe
#   ENum: 1672562
#   Y: 5416525.81
#   X: 480016.96
#   Longitude: 8.727331063424588
#   Latitude: 48.90135498860808
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.727331063424588, 48.90135498860808]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1806
#   Gemeinde: Pforzheim
#   StraÃŸe: Wurmberger StraÃŸe
#   ENum: 1652885
#   Y: 5416532.19
#   X: 480103.53
#   Longitude: 8.72851198786443
#   Latitude: 48.90141516777291
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.72851198786443, 48.90141516777291]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1047
#   Gemeinde: Pforzheim
#   StraÃŸe: Wurmberger StraÃŸe
#   ENum: 1854656
#   Y: 5416531.71
#   X: 480083.98
#   Longitude: 8.728245253994377
#   Latitude: 48.90141022157028
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.728245253994377, 48.90141022157028]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1338
#   Gemeinde: Pforzheim
#   StraÃŸe: Wurmberger StraÃŸe
#   ENum: 1965966
#   Y: 5416528.55
#   X: 480043.65
#   Longitude: 8.727695110743127
#   Latitude: 48.90138049721487
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.727695110743127, 48.90138049721487]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1732
#   Gemeinde: Pforzheim
#   StraÃŸe: WÃ¼rmer HauptstraÃŸe
#   ENum: 1652437
#   Y: 5413444.7
#   X: 480572.31
#   Longitude: 8.735055208336105
#   Latitude: 48.87365592527955
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.735055208336105, 48.87365592527955]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1733
#   Gemeinde: Pforzheim
#   StraÃŸe: WÃ¼rmer HauptstraÃŸe
#   ENum: 1652439
#   Y: 5413522.36
#   X: 480673.43
#   Longitude: 8.736430545450439
#   Latitude: 48.87435769305745
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.736430545450439, 48.87435769305745]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1220
#   Gemeinde: Pforzheim
#   StraÃŸe: WÃ¼rmer HauptstraÃŸe
#   ENum: 1926151
#   Y: 5413551.3
#   X: 480730.11
#   Longitude: 8.737202156676684
#   Latitude: 48.87461979337825
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.737202156676684, 48.87461979337825]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1884
#   Gemeinde: Pforzheim
#   StraÃŸe: WÃ¼rmtalstraÃŸe
#   ENum: 1652542
#   Y: 5413777.67
#   X: 480603.52
#   Longitude: 8.735465036838319
#   Latitude: 48.87665220607919
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.735465036838319, 48.87665220607919]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1227
#   Gemeinde: Pforzheim
#   StraÃŸe: ZehnthofstraÃŸe
#   ENum: 1469123
#   Y: 5416977.82
#   X: 478371.87
#   Longitude: 8.704860138388481
#   Latitude: 48.90536585488993
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.704860138388481, 48.90536585488993]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1377
#   Gemeinde: Pforzheim
#   StraÃŸe: ZehnthofstraÃŸe
#   ENum: 1560894
#   Y: 5417026.66
#   X: 478513.02
#   Longitude: 8.706783690052868
#   Latitude: 48.90581011539872
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.706783690052868, 48.90581011539872]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1531
#   Gemeinde: Pforzheim
#   StraÃŸe: ZehnthofstraÃŸe
#   ENum: 2019192
#   Y: 5417012.86
#   X: 478479.2
#   Longitude: 8.706322908266566
#   Latitude: 48.90568480119484
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.706322908266566, 48.90568480119484]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1535
#   Gemeinde: Pforzheim
#   StraÃŸe: ZehnthofstraÃŸe
#   ENum: 2018974
#   Y: 5417012.93
#   X: 478479.38
#   Longitude: 8.706325360858544
#   Latitude: 48.90568543714483
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.706325360858544, 48.90568543714483]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/981
#   Gemeinde: Pforzheim
#   StraÃŸe: ZehnthofstraÃŸe
#   ENum: 1807884
#   Y: 5417000.62
#   X: 478401.26
#   Longitude: 8.70525998584894
#   Latitude: 48.90557198126326
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.70525998584894, 48.90557198126326]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/977
#   Gemeinde: Pforzheim
#   StraÃŸe: ZeisigstraÃŸe
#   ENum: 1820818
#   Y: 5417977.12
#   X: 481499.84
#   Longitude: 8.747499001044662
#   Latitude: 48.91445656374105
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.747499001044662, 48.91445656374105]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1122
#   Gemeinde: Pforzheim
#   StraÃŸe: ZerrennerstraÃŸe
#   ENum: 1431829
#   Y: 5417107.53
#   X: 477604.33
#   Longitude: 8.694379240197188
#   Latitude: 48.90650539934695
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.694379240197188, 48.90650539934695]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1163
#   Gemeinde: Pforzheim
#   StraÃŸe: ZerrennerstraÃŸe
#   ENum: 1417377
#   Y: 5417124.04
#   X: 477743.1
#   Longitude: 8.696272026134505
#   Latitude: 48.90665892003397
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.696272026134505, 48.90665892003397]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1164
#   Gemeinde: Pforzheim
#   StraÃŸe: ZerrennerstraÃŸe
#   ENum: 1417379
#   Y: 5417123.3
#   X: 477745.65
#   Longitude: 8.696306864444105
#   Latitude: 48.90665235490143
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.696306864444105, 48.90665235490143]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1987
#   Gemeinde: Pforzheim
#   StraÃŸe: ZerrennerstraÃŸe
#   ENum: 1730793
#   Y: 5417107.54
#   X: 477604.23
#   Longitude: 8.694377875026733
#   Latitude: 48.90650548568703
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.694377875026733, 48.90650548568703]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1450
#   Gemeinde: Pforzheim
#   StraÃŸe: ZerrennerstraÃŸe
#   ENum: 1998230
#   Y: 5417099.67
#   X: 477567.42
#   Longitude: 8.693875990175739
#   Latitude: 48.90643335779954
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.693875990175739, 48.90643335779954]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/901
#   Gemeinde: Pforzheim
#   StraÃŸe: ZerrennerstraÃŸe
#   ENum: 1807950
#   Y: 5417109.58
#   X: 477581.63
#   Longitude: 8.694069358466331
#   Latitude: 48.90652301909233
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.694069358466331, 48.90652301909233]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1460
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum Geigersgrund
#   ENum: 1592977
#   Y: 5418499.41
#   X: 476562.48
#   Longitude: 8.68008200708174
#   Latitude: 48.91898766089039
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.68008200708174, 48.91898766089039]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1767
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum Geigersgrund
#   ENum: 1633961
#   Y: 5418500.35
#   X: 476562.1
#   Longitude: 8.680076766230346
#   Latitude: 48.91899610236989
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.680076766230346, 48.91899610236989]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1807
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum Geigersgrund
#   ENum: 1652720
#   Y: 5418652.89
#   X: 476504.15
#   Longitude: 8.679276986337902
#   Latitude: 48.92036609458516
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.679276986337902, 48.92036609458516]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/903
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum Geigersgrund
#   ENum: 1791217
#   Y: 5418493.87
#   X: 476564.6
#   Longitude: 8.680111262474659
#   Latitude: 48.91893790551111
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.680111262474659, 48.91893790551111]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1820
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum HÃ¶henfreibad
#   ENum: 1652716
#   Y: 5418663.18
#   X: 479206.14
#   Longitude: 8.716158657038886
#   Latitude: 48.92055532322519
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.716158657038886, 48.92055532322519]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 1821
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum HÃ¶henfreibad
#   ENum: 1652718
#   Y: 5418661.76
#   X: 479207.73
#   Longitude: 8.716180433031619
#   Latitude: 48.92054260283999
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.716180433031619, 48.92054260283999]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/906
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum HÃ¶henfreibad
#   ENum: 1808207
#   Y: 5418641.87
#   X: 479196.31
#   Longitude: 8.716025563586351
#   Latitude: 48.9203632960435
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.716025563586351, 48.9203632960435]
#
# ------------------------------
#
# Feature Properties:
#   id_failure: 82300002/1091
#   Gemeinde: Pforzheim
#   StraÃŸe: Zum LachenwÃ¤ldle
#   ENum: 1885987
#   Y: 5416400.07
#   X: 474873.36
#   Longitude: 8.657155466222568
#   Latitude: 48.90003658722886
# Feature Geometry:
#   Type: Point
#   Coordinates: [8.657155466222568, 48.90003658722886]
#
# ------------------------------

# %% [markdown]
# ### a. Plotting a map with clustered markers, providing a clear representation of the failures (point) data, using the MarkerCluster plugin from the Folium library

# %%
# Create a folium map centered on the average latitude and longitude
map_center = [failuers_geo['Latitude'].mean(), failuers_geo['Longitude'].mean()]
map = folium.Map(location=map_center, zoom_start=10)

# Add MarkerCluster to the map
marker_cluster = MarkerCluster().add_to(map)

# Add markers to the MarkerCluster
for idx, row in failuers_geo.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"ID: {row['id_failure']}",
    ).add_to(marker_cluster)

# Display the map in the notebook
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5935229d41f3389a5c695a80c70aad56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5935229d41f3389a5c695a80c70aad56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5935229d41f3389a5c695a80c70aad56 = L.map(
#                 &quot;map_5935229d41f3389a5c695a80c70aad56&quot;,
#                 {
#                     center: [48.899791790901304, 8.702149314632841],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1212aa92f9d2d11f6c31ba005313989 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_d1212aa92f9d2d11f6c31ba005313989.addTo(map_5935229d41f3389a5c695a80c70aad56);
#
#             var marker_cluster_dd945b5a1805d055f47e718d37d61328 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_e2417caa16149f5aa2a4142e6c184026 = L.marker(
#                 [48.90906384828052, 8.690887438392448],
#                 {}
#             ).addTo(marker_cluster_dd945b5a1805d055f47e718d37d61328);
#
#
#         var popup_fd54ed76fbfdffcc9b1b6f7035207b9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54ae88f72409d9c7461b7d22794c8fb6 = $(`&lt;div id=&quot;html_54ae88f72409d9c7461b7d22794c8fb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 1070&lt;/div&gt;`)[0];
#                 popup_fd54ed76fbfdffcc9b1b6f7035207b9d.setContent(html_54ae88f72409d9c7461b7d22794c8fb6);
#
#
#
#         marker_e2417caa16149f5aa2a4142e6c184026.bindPopup(popup_fd54ed76fbfdffcc9b1b6f7035207b9d)
#         ;
#
#
#
#
#             var marker_f2006ebdcd82220422d2804ae4903f7a = L.marker(
#                 [48.90939097796691, 8.690937143454097],
#                 {}
#             ).addTo(marker_cluster_dd945b5a1805d055f47e718d37d61328);
#
#
#         var popup_5c8b009eee07cecebbe11e18156b598c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_209c500882dacd55f1cc3388f4b7d45f = $(`&lt;div id=&quot;html_209c500882dacd55f1cc3388f4b7d45f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 2068&lt;/div&gt;`)[0];
#                 popup_5c8b009eee07cecebbe11e18156b598c.setContent(html_209c500882dacd55f1cc3388f4b7d45f);
#
#
#
#         marker_f2006ebdcd82220422d2804ae4903f7a.bindPopup(popup_5c8b009eee07cecebbe11e18156b598c)
#         ;
#
#
#
#
#             var marker_fbc2b22c7685203a4788804d86b45d35 = L.marker(
#                 [48.90819427243528, 8.690334507586583],
#                 {}
#             ).addTo(marker_cluster_dd945b5a1805d055f47e718d37d61328);
#
#
#         var popup_47c7f3ab2abe9924c4af3bf188f52752 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7444e43095380c61dfc5907a87019829 = $(`&lt;div id=&quot;html_7444e43095380c61dfc5907a87019829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 82300002/1007&lt;/div&gt;`)[0];
#                 popup_47c7f3ab2abe9924c4af3bf188f52752.setContent(html_7444e43095380c61dfc5907a87019829);
#
#
#
#         marker_fbc2b22c7685203a4788804d86b45d35.bindPopup(popup_47c7f3ab2abe9924c4af3bf188f52752)
#         ;
#
#
#
#
#             var marker_4278cd807756a8a00221a4256d2fe2fb = L.marker(
#                 [48.88472467948091, 8.684424416876592],
#                 {}
#             ).addTo(marker_cluster_dd945b5a1805d055f47e718d37d61328);
#
#
#         var popup_16af83dac5738f1b1d0daaa5cbfd3f69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b5c90ec598f5e0033a30f1782b00649 = $(`&lt;div id=&quot;html_7b5c90ec598f5e0033a30f1782b00649&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID: 1001&lt;/div&gt;`)[0];
#                 popup_16af83dac5738f1b1d0daaa5cbfd3f69.setContent(html_7b5c90ec598f5e0033a30f1782b00649);
#
#
#
#         marker_4278cd807756a8a00221a4256d2fe2fb.bindPopup(popup_16af83dac5738f1b1d0daaa5cbfd3f69)
#         ;
#
#
#
#
#             var marker_7ea15d307a648880edbc003fb79f2f53 = L.marker(
#                 [48.88371519405548, 8.682271382184158],
#                 {}
#             ).

# %%
# Save the map as an HTML file
map_output_path = r'C:\Users\Sanja\Documents\11-2023 Water Loss Project\04 Analysis\Visualizations\cluster_failures.html'
map.save(map_output_path)

# %% [markdown]
# ### b. Plotting a heatmap that visually represents the density of failure points on the map, using the HeatMap plugin from the Folium library¶

# %%
# Create a list to store the coordinates for the heatmap
heatmap_data = []

# Iterate through the GeoJSON features
for feature in data['features']:
    # Append the coordinates to the heatmap_data list
    heatmap_data.append([feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]])

# Setup a folium map at a high-level zoom
map_center = [data['features'][0]['geometry']['coordinates'][1], data['features'][0]['geometry']['coordinates'][0]]
map = folium.Map(location=map_center, zoom_start=10)

# Add a HeatMap layer to the map using the heatmap_data
HeatMap(heatmap_data).add_to(map)

# Custom legend HTML and CSS
legend_html = '''
     <div style="position: fixed; bottom: 50px; left: 50px; z-index:1000; background-color:white; padding: 10px; border:1px solid grey; font-size:14px;">
     <p><strong>Legend</strong></p>
     <p><span style="background-color: #0000FF; padding: 5px;"></span> Low Density</p>
     <p><span style="background-color: #00FF00; padding: 5px;"></span> Medium Density</p>
     <p><span style="background-color: #FF0000; padding: 5px;"></span> High Density</p>
     <!-- Add more lines as needed -->
     </div>
'''

# Display the custom legend
map.get_root().html.add_child(folium.Element(legend_html))

# Display the map in the notebook
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf0f67a8e73492231b27dfd2b7d3b33b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; z-index:1000; background-color:white; padding: 10px; border:1px solid grey; font-size:14px;&quot;&gt;
#      &lt;p&gt;&lt;strong&gt;Legend&lt;/strong&gt;&lt;/p&gt;
#      &lt;p&gt;&lt;span style=&quot;background-color: #0000FF; padding: 5px;&quot;&gt;&lt;/span&gt; Low Density&lt;/p&gt;
#      &lt;p&gt;&lt;span style=&quot;background-color: #00FF00; padding: 5px;&quot;&gt;&lt;/span&gt; Medium Density&lt;/p&gt;
#      &lt;p&gt;&lt;span style=&quot;background-color: #FF0000; padding: 5px;&quot;&gt;&lt;/span&gt; High Density&lt;/p&gt;
#      &lt;!-- Add more lines as needed --&gt;
#      &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf0f67a8e73492231b27dfd2b7d3b33b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf0f67a8e73492231b27dfd2b7d3b33b = L.map(
#                 &quot;map_cf0f67a8e73492231b27dfd2b7d3b33b&quot;,
#                 {
#                     center: [48.90906384828052, 8.690887438392448],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b4a28ececcd2808c696ca627edc3609 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer
# Merge the two dataframes: GeoDataFrame 'failuers_geo' and the dataframe 'data_to_plot'
merged_geo_df = pd.merge(failuers_geo, data_to_plot, on='id_failure', how='inner')

# %%
merged_geo_df
# Out:
#         id_failure   Gemeinde            Straße     ENum           Y  \
# 0    82300002/1007  Pforzheim     Belfortstraße  1820500  5417296.47
# 1    82300002/1175  Pforzheim      Belremstraße  1908046  5413979.82
# 2    82300002/1375  Pforzheim         Birkenweg  1976665  5416259.27
# 3    82300002/1480  Pforzheim      Bleichstraße  2010565  5416164.71
# 4     82300002/999  Pforzheim      Bleichstraße  1854354  5416621.20
# ..             ...        ...               ...      ...         ...
# 463  82300002/1450  Pforzheim   Zerrennerstraße  1998230  5417099.67
# 464   82300002/901  Pforzheim   Zerrennerstraße  1807950  5417109.58
# 465   82300002/903  Pforzheim  Zum Geigersgrund  1791217  5418493.87
# 466   82300002/906  Pforzheim  Zum Höhenfreibad  1808207  5418641.87
# 467  82300002/1091  Pforzheim  Zum Lachenwäldle  1885987  5416400.07
#
#              X  Longitude   Latitude                  geometry  \
# 0    477308.70   8.690335  48.908194  POINT (8.69033 48.90819)
# 1    476072.08   8.673653  48.878312  POINT (8.67365 48.87831)
# 2    479964.30   8.726626  48.898956  POINT (8.72663 48.89896)
# 3    477749.58   8.696413  48.898029  POINT (8.69641 48.89803)
# 4    477793.89   8.696992  48.902137  POINT (8.69699 48.90214)
# ..         ...        ...        ...                       ...
# 463  477567.42   8.693876  48.906433  POINT (8.69388 48.90643)
# 464  477581.63   8.694069  48.906523  POINT (8.69407 48.90652)
# 465  476564.60   8.680111  48.918938  POINT (8.68011 48.91894)
# 466  479196.31   8.716026  48.920363  POINT (8.71603 48.92036)
# 467  474873.36   8.657155  48.900037  POINT (8.65716 48.90004)
#
#      cause_of_damage
# 0                3.0
# 1                2.0
# 2                3.0
# 3                2.0
# 4                2.0
# ..               ...
# 463              3.0
# 464              3.0
# 465              0.0
# 466              2.0
# 467              3.0
#
# [468 rows x 10 columns]

# %% [markdown]
# #### Map Causes:

# %%
# Map the causes to the GeoJSON features
failuers_geo['cause_of_damage'] = merged_geo_df['cause_of_damage']

# %%
# Create a map centered around the mean coordinates of your GeoDataFrame
mean_lat = merged_geo_df['Latitude'].mean()
mean_lon = merged_geo_df['Longitude'].mean()

# Create a color dictionary for different causes
cause_colors = {
    '2.0': 'red',
    '3.0': 'blue',
    '6.0': 'gray',
    '1.0': 'gray',
}


# Convert keys to strings to ensure consistency
cause_colors = {str(key): value for key, value in cause_colors.items()}

# Default color for unknown causes
default_color = 'gray'

# Ensure default_color is a string
default_color = str(default_color)

map_causes = folium.Map(location=[mean_lat, mean_lon], zoom_start=12)

# Create a FeatureGroup for each cause color
cause_groups = {color: plugins.FeatureGroupSubGroup(map_causes, color) for color in cause_colors.values()}
cause_groups[default_color] = plugins.FeatureGroupSubGroup(map_causes, default_color)  # Add FeatureGroup for default color

# Iterate through GeoDataFrame rows and add markers to the map
for idx, row in merged_geo_df.iterrows():
    cause = str(row['cause_of_damage'])
    
    # Check for NaN values and assign a default color
    if pd.isna(cause):
        color = default_color
    else:
        # Assign a default color for unknown causes
        color = cause_colors.get(cause, default_color)
    
    folium.Marker([row['Latitude'], row['Longitude']], popup=cause, icon=folium.Icon(color=color)).add_to(cause_groups[color])

# Add each FeatureGroup to the map
for cause, group in cause_groups.items():
    map_causes.add_child(group)
    map_causes.get_root().add_child(folium.Element(f'<p style="color:{cause}">{cause}</p>'))

# Add a Legend
legend_html = '''
     <div style="position: fixed; 
                 bottom: 50px; left: 50px; width: 150px; height: 90px; 
                 border:2px solid grey; z-index:9999; font-size:14px;
                 background-color:white;
                 ">&nbsp; Cause Legend <br>
                 &nbsp; Code: 2.0 &nbsp; <i class="fa fa-circle fa-1x" style="color:red"></i><br>
                 &nbsp; Code: 3.0 &nbsp; <i class="fa fa-circle fa-1x" style="color:blue"></i><br>
                 &nbsp; Other &nbsp; <i class="fa fa-circle fa-1x" style="color:gray"></i>
      </div>
     '''

map_causes.get_root().html.add_child(folium.Element(legend_html))

# Add a LayerControl to the map
folium.LayerControl(collapsed=False).add_to(map_causes)

# Display the map in the notebook
display(map_causes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_509ec8000cc418d150ef50ab4b871736 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;div style=&quot;position: fixed;
#                  bottom: 50px; left: 50px; width: 150px; height: 90px;
#                  border:2px solid grey; z-index:9999; font-size:14px;
#                  background-color:white;
#                  &quot;&gt;&amp;nbsp; Cause Legend &lt;br&gt;
#                  &amp;nbsp; Code: 2.0 &amp;nbsp; &lt;i class=&quot;fa fa-circle fa-1x&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&lt;br&gt;
#                  &amp;nbsp; Code: 3.0 &amp;nbsp; &lt;i class=&quot;fa fa-circle fa-1x&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;&lt;br&gt;
#                  &amp;nbsp; Other &amp;nbsp; &lt;i class=&quot;fa fa-circle fa-1x&quot; style=&quot;color:gray&quot;&gt;&lt;/i&gt;
#       &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_509ec8000cc418d150ef50ab4b871736&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_509ec8000cc418d150ef50ab4b871736 = L.map(
#                 &quot;map_509ec8000cc418d150ef50ab4b871736&quot;,
#                 {
#                     center: [48.89998981507034, 8.702224245285933],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9f9a5b443fef589411620cf6b44b4ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a9f9a5b443fef589411620cf6b44b4ab.addTo(map_509ec8000cc418d150ef50ab4b871736);
#
#             var feature_group_sub_group_65242e89b05ccdf20648b9982c837e5e = L.featureGroup.subGroup(
#                 map_509ec8000cc418d150ef50ab4b871736
#             );
#
#
#             var marker_263afae6c309eb749ea02db45f618aaa = L.marker(
#                 [48.87831234358177, 8.673653030192822],
#                 {}
#             ).addTo(feature_group_sub_group_65242e89b05ccdf20648b9982c837e5e);
#
#
#             var icon_9b658cfaa40c3aa6ea1a35358b1051bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_263afae6c309eb749ea02db45f618aaa.setIcon(icon_9b658cfaa40c3aa6ea1a35358b1051bb);
#
#
#         var popup_fd9cfa27aaf72e020405df80909db427 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86fc064f0f235b2e38b59caf5f419deb = $(`&lt;div id=&quot;html_86fc064f0f235b2e38b59caf5f419deb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2.0&lt;/div&gt;`)[0];
#                 popup_fd9cfa27aaf72e020405df80909db427.setContent(html_86fc064f0f235b2e38b59caf5f419deb);
#
#
#
#         marker_263afae6c309eb749ea02db45f618aaa.bindPopup(popup_fd9cfa27aaf72e020405df80909db427)
#         ;
#
#
#
#
#             var marker_02768b1205c378dc9c9b13159cb05fba = L.marker(
#                 [48.89802936251423, 8.696412727477696],
#                 {}
#             ).addTo(feature_group_sub_group_65242e89b05ccdf20648b9982c837e5e);
#
#
#             var icon_ebcfeb98d29b30dfea3dc0783cd77fc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_02768b1205c378dc9c9b13159cb05fba.setIcon(icon_ebcfeb98d29b30dfea3dc0783cd77fc3);
#
#
#         var popup_55f7a46e9e60e10c6402d36231efa600 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc75722585753eb7f36caa8b37e2f8cd = $(`&lt;div id=&quot;html_fc75722585753eb7f36caa8b37e2f8cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2.0&lt;/div&gt;`)[0];
#                 popup_55f7a46e9e60e10c6402d36231efa600.setContent(html_fc75722585753eb7f36caa8b37e2f8cd);
#
#
#
#         marker_02768b1205c378dc9c9b13159cb05fba.bindPopup(popup_55f7a46e9e60e10c6402d36231efa600)
#         ;
#
#
#
#
#             var marker_c6b891a11c5d259cb403955c10c1860d = L.marker(
#                 [48.9021373754336, 8.696992467974274],
#                 {}
#             ).addTo(feature_group_sub_group_65242e89b05ccdf20648b9982c837e5e);
#
#
#             var icon_ede8db4db9b044a0a6ed775d053326f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&q

# %%
# Save the map as an HTML file
map_causes_output_path = r'C:\Users\Sanja\Documents\11-2023 Water Loss Project\04 Analysis\Visualizations\map_failures_causes.html'
map.save(map_causes_output_path)

# %% [markdown]
# ### Observation:
# I've created three types of maps:
# #### 1. Folium map with clustered markers:
# - Provides a clear representation of the locations of failures (points) on the map.
# - Clustering helps in visualizing densely populated areas with a large number of failure points.
# - Allows for an overview of the geographical distribution of failures.
# #### 2. Heatmap that visually represents the density of failure points on the map
# - Visually represents the density of failure points on the map.
# - Highlights areas with higher concentrations of failures.
# #### 3. Map with markers representing points from a GeoDataFrame, with each marker color-coded based on a cause of damage.
# - Provides insights into the causes of failures by color-coding markers.
# - Allows for the identification of specific causes in different geographical areas.
# ### Overall Observations:
# The combination of the three maps offers a comprehensive view of the failure data from different perspectives.
# The clustered marker map and heatmap focus on the geographical distribution and density of failures, while the color-coded map provides insights into the causes of these failures.
# These visualizations can aid in identifying patterns, hotspots, and potential correlations between geographical locations and causes of failures.
# ### Research Questions:
# #### Existing Research Questions:
# The maps provide a spatial understanding of failure occurrences, but additional analysis is required to answer specific research questions.
# Consideration of temporal aspects could enhance the analysis (e.g., changes in failure patterns over time).
# #### New Research Questions:
# Are there specific clusters of failures that coincide with particular causes?
# How has the distribution of failures changed over time, if applicable?
# Are there any geographical or environmental factors contributing to the observed patterns?
# ####  Possibilities for testing hypotheses based on the maps and data visualizations:
# ##### Hypothesis 1: There is a spatial correlation between the geographical distribution of failure clusters and specific environmental factors.
# ##### Hypothesis 2: Failures with similar causes tend to cluster in specific geographical regions.
# ##### Hypothesis 3: The frequency and causes of failures vary over time.
